# %%
import matplotlib.pyplot as plt
import numpy as np
from imageio import imread, imsave
from skimage.color import rgb2gray
import cv2
import os
import numpy as np

# %%
def walker(source = "./images"):
    for link, dirs, files in list(os.walk(source)):
        for file in files:
            yield link + '//' + file

# %%
y_scaler = 4
x_scaler = 4

for file in walker():
    print(file)
    img_name = file.split("/")[-1]
    img_name = img_name.split(".")[0]
    print(img_name)
    img = imread(file)
#     img = imread(file)
    print("\t", img.shape)
    width, height = int(img.shape[0] / x_scaler), int(img.shape[1] / x_scaler)
    for i in range(y_scaler):
        for j in range(x_scaler):
            img_mean = np.mean(img[i*height:(i+1)*height, j*width:(j+1)*width])
            if img_mean > 0.05:
                print("\t\t", np.mean(img[i*height:(i+1)*height, j*width:(j+1)*width]))
                print("nice_images/" + f"{img_name}_{i}_{j}.")
                imsave("nice_images/" + f"{img_name}_{i}_{j}.tif", img[i*height:(i+1)*height, j*width:(j+1)*width])
#     print(np.mean(img))
# Out:
# ./images//Fas3_1_1.tif
# Fas3_1_1
# 	 (2048, 2048, 3)
# 		 3.13201904296875
# nice_images/Fas3_1_1_0_0.
# 		 28.600452423095703
# nice_images/Fas3_1_1_0_1.
# 		 5.123714447021484
# nice_images/Fas3_1_1_0_2.
# 		 31.95586395263672
# nice_images/Fas3_1_1_1_0.
# 		 52.5388069152832
# nice_images/Fas3_1_1_1_1.
# 		 34.046260833740234
# nice_images/Fas3_1_1_1_2.
# 		 5.5705108642578125
# nice_images/Fas3_1_1_1_3.
# 		 19.885543823242188
# nice_images/Fas3_1_1_2_0.
# 		 48.69462966918945
# nice_images/Fas3_1_1_2_1.
# 		 63.88208770751953
# nice_images/Fas3_1_1_2_2.
# 		 36.552581787109375
# nice_images/Fas3_1_1_2_3.
# 		 4.853511810302734
# nice_images/Fas3_1_1_3_2.
# 		 9.524398803710938
# nice_images/Fas3_1_1_3_3.
# ./images//Fas3_1_2.tif
# Fas3_1_2
# 	 (2048, 2048, 3)
# 		 3.3296890258789062
# nice_images/Fas3_1_2_0_0.
# 		 31.8233642578125
# nice_images/Fas3_1_2_0_1.
# 		 5.2067413330078125
# nice_images/Fas3_1_2_0_2.
# 		 41.853248596191406
# nice_images/Fas3_1_2_1_0.
# 		 65.78237533569336
# nice_images/Fas3_1_2_1_1.
# 		 35.242496490478516
# nice_images/Fas3_1_2_1_2.
# 		 5.555824279785156
# nice_images/Fas3_1_2_1_3.
# 		 22.004390716552734
# nice_images/Fas3_1_2_2_0.
# 		 48.62686538696289
# nice_images/Fas3_1_2_2_1.
# 		 66.72978210449219
# nice_images/Fas3_1_2_2_2.
# 		 43.0819206237793
# nice_images/Fas3_1_2_2_3.
# 		 5.135017395019531
# nice_images/Fas3_1_2_3_2.
# 		 10.469673156738281
# nice_images/Fas3_1_2_3_3.
# ./images//Fas3_1_3.tif
# Fas3_1_3
# 	 (2048, 2048, 3)
# 		 3.1184463500976562
# nice_images/Fas3_1_3_0_0.
# 		 30.134517669677734
# nice_images/Fas3_1_3_0_1.
# 		 5.046775817871094
# nice_images/Fas3_1_3_0_2.
# 		 43.85066604614258
# nice_images/Fas3_1_3_1_0.
# 		 65.74166107177734
# nice_images/Fas3_1_3_1_1.
# 		 33.545169830322266
# nice_images/Fas3_1_3_1_2.
# 		 5.254913330078125
# nice_images/Fas3_1_3_1_3.
# 		 22.40018081665039
# nice_images/Fas3_1_3_2_0.
# 		 47.76325607299805
# nice_images/Fas3_1_3_2_1.
# 		 64.73465728759766
# nice_images/Fas3_1_3_2_2.
# 		 43.63666915893555
# nice_images/Fas3_1_3_2_3.
# 		 4.975955963134766
# nice_images/Fas3_1_3_3_2.
# 		 10.506599426269531
# nice_images/Fas3_1_3_3_3.
